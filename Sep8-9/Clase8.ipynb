# %%
# !pip install scienceplots

# %%
# !git clone https://github.com/DCI-alxogm/ml2023-PotterSR.git
# Out:
# Cloning into 'ml2023-PotterSR'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 126 (delta 40), reused 102 (delta 20), pack-reused 0
# Receiving objects: 100% (126/126), 3.04 MiB | 17.30 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import scienceplots
plt.style.use(['science', 'no-latex'])

# %%
houses = np.loadtxt('/content/ml2023-PotterSR/Data/houses.txt', delimiter = ',')
Xh = houses[:,:4]
th = houses[:, 4]

labels = ['Size', 'Rooms', 'Floors', 'Years']

# %%
scaler = StandardScaler()
Xh_norm = scaler.fit_transform(Xh) #Normalizamos los datos

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3))

for i in range(len(ax)):
    ax[i].hist(Xh[:, i]);
    ax[i].set_title(labels[i]);
fig.suptitle('Distribution After Normalize')
plt.show()


fig,ax=plt.subplots(1, 4, figsize=(12, 3))
for i in range(len(ax)):
    ax[i].hist(Xh_norm[:,i]);
    ax[i].set_xlabel(labels[i]);
fig.suptitle('Distribution Before Normalize')
plt.show()

# %%
sgdr = SGDRegressor(max_iter = 1000, learning_rate='constant', eta0=0.01)
sgdr.fit(Xh_norm, th)

print(sgdr)
print(f'Number of iterations completed:  {sgdr.n_iter_}, number of weight updates: {sgdr.t_}')
# Out:
# SGDRegressor(learning_rate='constant')
# Number of iterations completed:  33, number of weight updates: 3301.0

# %%
w0_norm = sgdr.intercept_
w_norm = sgdr.coef_
print(f"model parameters:  w: {w0_norm}, b:{w_norm}")
# Out:
# model parameters:  w: [361.84119773], b:[110.62144946 -21.60945128 -32.62700888 -38.44809958]

# %%
#predict target using normalized features
yp = w0_norm[0]
for i in range(len(w_norm)):
  yp+=w_norm[i]*Xh_norm[:,i]

    # plot predictions and targets versus original features
fig,ax=plt.subplots(1,4,figsize=(12, 3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(Xh[:,i],th, label = 'target')
    ax[i].scatter(Xh[:,i],yp,color="orange", label = 'predict')
ax[0].set_ylabel("Price"); ax[0].legend();
fig.suptitle("target versus prediction using normalized model")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(Xh_norm, th, test_size=0.30, random_state=42)

# %%
sgdr = SGDRegressor(max_iter=100, loss="squared_error",learning_rate='constant', eta0=0.01,penalty=None)
sgdr.fit(X_train, y_train)
print(sgdr)
print(f"number of iterations completed: {sgdr.n_iter_}, number of weight updates: {sgdr.t_}")
coeffs =sgdr.coef_
intercept = sgdr.intercept_
# Out:
# SGDRegressor(learning_rate='constant', max_iter=100, penalty=None)
# number of iterations completed: 33, number of weight updates: 2311.0

# %%
sgdr.score(X_test, y_test)
# Out:
# 0.9615281075038129

# %%
yp = intercept[0]
for i in range(len(w_norm)):
  yp+=coeffs[i]*X_test[:,i]

    # plot predictions and targets versus original features
fig,ax=plt.subplots(1,4,figsize=(12, 3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(X_test[:,i],y_test, label = 'target')
    ax[i].scatter(X_test[:,i],yp,color="orange", label = 'predict')
ax[0].set_ylabel("Price"); ax[0].legend();
fig.suptitle("target versus prediction")
plt.show()

# %% [markdown]
# ## Usando Keras SGD

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
100
# 1/1 [==============================] - 0s 23ms/step - loss: 9689.7910
# Epoch 72/100
# 1/1 [==============================] - 0s 21ms/step - loss: 9364.0723
# Epoch 73/100
# 1/1 [==============================] - 0s 21ms/step - loss: 9050.9004
# Epoch 74/100
# 1/1 [==============================] - 0s 15ms/step - loss: 8749.7822
# Epoch 75/100
# 1/1 [==============================] - 0s 14ms/step - loss: 8460.2363
# Epoch 76/100
# 1/1 [==============================] - 0s 17ms/step - loss: 8181.8052
# Epoch 77/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7914.0444
# Epoch 78/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7656.5288
# Epoch 79/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7408.8545
# Epoch 80/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7170.6323
# Epoch 81/100
# 1/1 [==============================] - 0s 16ms/step - loss: 6941.4858
# Epoch 82/100
# 1/1 [==============================] - 0s 16ms/step - loss: 6721.0527
# Epoch 83/100
# 1/1 [==============================] - 0s 12ms/step - loss: 6508.9937
# Epoch 84/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6304.9717
# Epoch 85/100
# 1/1 [==============================] - 0s 11ms/step - loss: 6108.6704
# Epoch 86/100
# 1/1 [==============================] - 0s 11ms/step - loss: 5919.7886
# Epoch 87/100
# 1/1 [==============================] - 0s 9ms/step - loss: 5738.0273
# Epoch 88/100
# 1/1 [==============================] - 0s 8ms/step - loss: 5563.1064
# Epoch 89/100
# 1/1 [==============================] - 0s 8ms/step - loss: 5394.7583
# Epoch 90/100
# 1/1 [==============================] - 0s 9ms/step - loss: 5232.7246
# Epoch 91/100
# 1/1 [==============================] - 0s 10ms/step - loss: 5076.7524
# Epoch 92/100
# 1/1 [==============================] - 0s 16ms/step - loss: 4926.6079
# Epoch 93/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4782.0601
# Epoch 94/100
# 1/1 [==============================] - 0s 11ms/step - loss: 4642.8867
# Epoch 95/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4508.8770
# Epoch 96/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4379.8311
# Epoch 97/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4255.5537
# Epoch 98/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4135.8569
# Epoch 99/100
# 1/1 [==============================] - 0s 15ms/step - loss: 4020.5613
# Epoch 100/100
# 1/1 [==============================] - 0s 8ms/step - loss: 3909.4929

# %%
capas = model.layers[0]
w, b = capas.get_weights()
print(w,b)
# Out:
# [[ 59.061714  ]
#  [  0.57608724]
#  [-14.79882   ]
#  [-49.55346   ]] [312.6024]

# %%
history_df = pd.DataFrame(history.history)

history_df['loss'].plot();

# %%
history2= model.fit(X_train, y_train, epochs=num_epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3802.4897
# Epoch 2/100
# 1/1 [==============================] - 0s 18ms/step - loss: 3699.3909
# Epoch 3/100
# 1/1 [==============================] - 0s 19ms/step - loss: 3600.0447
# Epoch 4/100
# 1/1 [==============================] - 0s 15ms/step - loss: 3504.3062
# Epoch 5/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3412.0325
# Epoch 6/100
# 1/1 [==============================] - 0s 16ms/step - loss: 3323.0898
# Epoch 7/100
# 1/1 [==============================] - 0s 19ms/step - loss: 3237.3499
# Epoch 8/100
# 1/1 [==============================] - 0s 15ms/step - loss: 3154.6853
# Epoch 9/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3074.9800
# Epoch 10/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2998.1167
# Epoch 11/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2923.9880
# Epoch 12/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2852.4863
# Epoch 13/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2783.5107
# Epoch 14/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2716.9629
# Epoch 15/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2652.7502
# Epoch 16/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2590.7822
# Epoch 17/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2530.9736
# Epoch 18/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2473.2410
# Epoch 19/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2417.5046
# Epoch 20/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2363.6890
# Epoch 21/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2311.7200
# Epoch 22/100
# 1/1 [==============================] - 0s 10ms/step - loss: 2261.5283
# Epoch 23/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2213.0454
# Epoch 24/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2166.2053
# Epoch 25/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2120.9460
# Epoch 26/100
# 1/1 [==============================] - 0s 20ms/step - loss: 2077.2090
# Epoch 27/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2034.9348
# Epoch 28/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1994.0697
# Epoch 29/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1954.5590
# Epoch 30/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1916.3534
# Epoch 31/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1879.4014
# Epoch 32/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1843.6583
# Epoch 33/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1809.0787
# Epoch 34/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1775.6176
# Epoch 35/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1743.2341
# Epoch 36/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1711.8885
# Epoch 37/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1681.5415
# Epoch 38/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1652.1569
# Epoch 39/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1623.6991
# Epoch 40/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1596.1324
# Epoch 41/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1569.4254
# Epoch 42/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1543.5463
# Epoch 43/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1518.4655
# Epoch 44/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1494.1521
# Epoch 45/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1470.5798
# Epoch 46/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1447.7206
# Epoch 47/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1425.5496
# Epoch 48/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1404.0403
# Epoch 49/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1383.1699
# Epoch 50/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1362.9161
# Epoch 51/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1343.2559
# Epoch 52/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1324.1682
# Epoch 53/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1305.6326
# Epoch 54/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1287.6302
# Epoch 55/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1270.1414
# Epoch 56/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1253.1478
# Epoch 57/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1236.6328
# Epoch 58/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1220.5787
# Epoch 59/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1204.9705
# Epoch 60/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1189.7915
# Epoch 61/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1175.0276
# Epoch 62/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1160.6641
# Epoch 63/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1146.6880
# Epoch 64/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1133.0853
# Epoch 65/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1119.8430
# Epoch 66/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1106.9501
# Epoch 67/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1094.3938
# Epoch 68/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1082.1625
# Epoch 69/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1070.2463
# Epoch 70/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1058.6337
# Epoch 71/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1047.3145
# Epoch 72/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1036.2805
# Epoch 73/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1025.5203
# Epoch 74/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1015.0266
# Epoch 75/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1004.7900
# Epoch 76/100
# 1/1 [==============================] - 0s 16ms/step - loss: 994.8017
# Epoch 77/100
# 1/1 [==============================] - 0s 13ms/step - loss: 985.0544
# Epoch 78/100
# 1/1 [==============================] - 0s 17ms/step - loss: 975.5399
# Epoch 79/100
# 1/1 [==============================] - 0s 13ms/step - loss: 966.2510
# Epoch 80/100
# 1/1 [==============================] - 0s 14ms/step - loss: 957.1807
# Epoch 81/100
# 1/1 [==============================] - 0s 15ms/step - loss: 948.3212
# Epoch 82/100
# 1/1 [==============================] - 0s 14ms/step - loss: 939.6670
# Epoch 83/100
# 1/1 [==============================] - 0s 15ms/step - loss: 931.2112
# Epoch 84/100
# 1/1 [==============================] - 0s 24ms/step - loss: 922.9476
# Epoch 85/100
# 1/1 [==============================] - 0s 21ms/step - loss: 914.8702
# Epoch 86/100
# 1/1 [==============================] - 0s 14ms/step - loss: 906.9738
# Epoch 87/100
# 1/1 [==============================] - 0s 13ms/step - loss: 899.2516
# Epoch 88/100
# 1/1 [==============================] - 0s 13ms/step - loss: 891.6992
# Epoch 89/100
# 1/1 [==============================] - 0s 18ms/step - loss: 884.3112
# Epoch 90/100
# 1/1 [==============================] - 0s 16ms/step - loss: 877.0832
# Epoch 91/100
# 1/1 [==============================] - 0s 14ms/step - loss: 870.0099
# Epoch 92/100
# 1/1 [==============================] - 0s 16ms/step - loss: 863.0872
# Epoch 93/100
# 1/1 [==============================] - 0s 19ms/step - loss: 856.3101
# Epoch 94/100
# 1/1 [==============================] - 0s 17ms/step - loss: 849.6743
# Epoch 95/100
# 1/1 [==============================] - 0s 29ms/step - loss: 843.1761
# Epoch 96/100
# 1/1 [==============================] - 0s 28ms/step - loss: 836.8114
# Epoch 97/100
# 1/1 [==============================] - 0s 20ms/step - loss: 830.5764
# Epoch 98/100
# 1/1 [==============================] - 0s 20ms/step - loss: 824.4673
# Epoch 99/100
# 1/1 [==============================] - 0s 15ms/step - loss: 818.4804
# Epoch 100/100
# 1/1 [==============================] - 0s 18ms/step - loss: 812.6126

# %%
capas = model.layers[0]
w, b = capas.get_weights()
print(w,b)
# Out:
# [[ 82.353645]
#  [ -9.564008]
#  [-23.690283]
#  [-47.320885]] [354.1073]

# %%
# convert the training history to a dataframe
history_df = pd.DataFrame(history2.history)
# use Pandas native plot method
history_df['loss'].plot();

# %%
score = model.evaluate(X_test, y_test, verbose=0)
score
# Out:
# 1178.2459716796875

# %%
yp = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3))

for i in range(len(ax)):
    ax[i].scatter(X_test[:,i],y_test, label = 'target')
    ax[i].scatter(X_test[:,i],yp,color="orange", label = 'predict')
ax[0].set_ylabel("Price"); ax[0].legend();
fig.suptitle("target versus prediction using KERAS")
plt.show()
